# %% [markdown]
# ### Problem
# - use if-else statement

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | method1

# %% [markdown]
# | method2

# %% [markdown]
# ### Problem
# - use function
# - use two function(solution, print_result)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | method1

# %% [markdown]
# | method2

# %% [markdown]
# ### Problem from kakao coding test

# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/17681?language=python3

# %% [markdown]
# | method1

# %%
arr1 = [9, 20, 28, 18, 11]
arr2 = [30, 1, 21, 17, 28]

arr3 = [46, 33, 33 ,22, 31, 50]
arr4 = [27 ,56, 19, 14, 14, 10]

def solution(n, arr1, arr2):
    pass
    answer = []
    return answer

# %% [markdown]
# | method2

# %% [markdown]
# | method3

# %% [markdown]
# | method4
